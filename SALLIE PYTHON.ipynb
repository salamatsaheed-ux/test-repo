# %%
print('hello world')
# Out:
# hello world

# %%
print('hi salamat')
# Out:
# hi salamat

# %%
print('welcome to your first python class')
# Out:
# welcome to your first python class

# %%
print("have fun in class")
# Out:
# have fun in class

# %%
print('hello')
print("how are you")
print('''have fun''')
# Out:
# hello
# how are you
# have fun

# %%
name='Salamat'
print(name)

x = 5
print(x)
# Out:
# Salamat
# 5

# %%
text="hello world, today is tuesday"

print(text)
print(text.upper())
print(text.lower())
print(text.title())
print(text.replace("world", "salamat"))
print(text.split())
# Out:
# hello world, today is tuesday
# HELLO WORLD, TODAY IS TUESDAY
# hello world, today is tuesday
# Hello World, Today Is Tuesday
# hello salamat, today is tuesday
# ['hello', 'world,', 'today', 'is', 'tuesday']

# %%
text = "python"
len(text)
# Out:
# 6

# %%
first = "Hello"
second = "python"
print(first + ' ' + second)
print(8+5)
print('8' + '5')
# Out:
# Hello python
# 13
# 85

# %%
text = "python"
print(text[0])
print(text[3])

print(text[-4])
print(text[-6])
# Out:
# p
# h
# t
# p

# %%
text = "Fellowship"
print(text[0:6])
print(text[3:6])
print(text[7:])
print(text[:-4])
print(text[-3:-1])
# Out:
# Fellow
# low
# hip
# Fellow
# hi

# %%
x = 6
y = 10
x,y = y, x
print(x, y)
# Out:
# 10 6

# %%
x = 15
y= 100
print(x)
print(y)
x,y = y, x
print(x)
print(y)
# Out:
# 15
# 100
# 100
# 15

# %%
text = 'Fellowship'
print(text[0::6])
print(text[-3:])
print(text[::-1])
print(text[:-4])
print(text[3:5])
print(text[7:])
# Out:
# Fs
# hip
# pihswolleF
# Fellow
# lo
# hip

# %%
s = ' salamat is a girl '
print(s)
print(s.capitalize())
print(s.split())
print(s.lower())
print(s.upper())
print(s.lstrip())
print(s.rstrip())
print(s.title())
print(s.replace('girl', 'muslim'))
print(s.find('salamat'))
print(s.count('a'))
print(s.startswith('hello'))
# Out:
#  salamat is a girl
#  salamat is a girl
# ['salamat', 'is', 'a', 'girl']
#  salamat is a girl
#  SALAMAT IS A GIRL
# salamat is a girl
#  salamat is a girl
#  Salamat Is A Girl
#  salamat is a muslim
# 1
# 4
# False

# %%
# using format
name = 'Salamah'
age = 22
print('my name is {0} and i am {1} years old.'.format(age, name))
# Out:
# my name is 22 and i am Salamah years old.

# %%
name = 'salamah'
age = 22
print(f'my name is {name} and i am {age} years old.')
# Out:
# my name is salamah and i am 22 years old.

# %%
print("Hello\nWorld")
print('Formation   rocks')
print(
# Out:
# Hello
# World
# Formation   rocks
